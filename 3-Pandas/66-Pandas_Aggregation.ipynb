# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Data

# %%
df = pd.read_csv("ibb_weather.csv")

# %% [markdown]
# #### Aggregation
# Combiningmultiple pieces of data into a single result

# %%
df
# Out:
#                  DATE_TIME            OBSERVATORY_NAME  \
# 0      2020-01-15 00:00:00       BEYKOZ_ANADOLU_FENERI
# 1      2020-01-18 09:00:00             ISTOC_MAHMUTBEY
# 2      2020-01-08 08:00:00  GUNGOREN_DAVUTPASA_MARMARA
# 3      2020-01-15 20:00:00                      KILYOS
# 4      2020-01-08 02:00:00  GUNGOREN_DAVUTPASA_MARMARA
# ...                    ...                         ...
# 53129  2020-01-19 11:00:00        B_CEKMECE_SVIRAJLARI
# 53130  2020-01-17 18:00:00                      PENDIK
# 53131  2020-01-11 13:00:00         KADIKOY_GOZTEPE_MGM
# 53132  2020-01-31 03:00:00           BEYLIKDUZU_H_DERE
# 53133  2020-01-15 12:00:00         CEKMEKOY_OMERLI_MGM
#
#                     SENSOR_TYPE  MINIMUM_TEMPERATURE  MAXIMUM_TEMPERATURE  \
# 0      AUTOMATED_WEATHER_SENSOR                6.800                7.000
# 1                  ICING_SENSOR                7.520                8.340
# 2      AUTOMATED_WEATHER_SENSOR                4.600                5.100
# ...

# %%
df.head(15)
# Out:
#               DATE_TIME            OBSERVATORY_NAME               SENSOR_TYPE  \
# 0   2020-01-15 00:00:00       BEYKOZ_ANADOLU_FENERI  AUTOMATED_WEATHER_SENSOR
# 1   2020-01-18 09:00:00             ISTOC_MAHMUTBEY              ICING_SENSOR
# 2   2020-01-08 08:00:00  GUNGOREN_DAVUTPASA_MARMARA  AUTOMATED_WEATHER_SENSOR
# 3   2020-01-15 20:00:00                      KILYOS  AUTOMATED_WEATHER_SENSOR
# 4   2020-01-08 02:00:00  GUNGOREN_DAVUTPASA_MARMARA  AUTOMATED_WEATHER_SENSOR
# 5   2020-01-15 06:00:00                 SILE_DARLIK  AUTOMATED_WEATHER_SENSOR
# 6   2020-01-04 07:00:00                     PASAKOY              ICING_SENSOR
# 7   2020-01-08 11:00:00              SANCAKTEPE_MGM  AUTOMATED_WEATHER_SENSOR
# 8   2020-01-22 11:00:00                     ESENLER              ICING_SENSOR
# 9   2020-01-01 14:00:00           HACIOSMAN_SARIYER              ICING_SENSOR
# 10  2020-01-28 18:00:00                 SILE_ISAKOY  AUTOMATED_WEATHER_SENSOR
# ...

# %%
df["OBSERVATORY_NAME"].head(10)
# Out:
# 0         BEYKOZ_ANADOLU_FENERI
# 1               ISTOC_MAHMUTBEY
# 2    GUNGOREN_DAVUTPASA_MARMARA
# 3                        KILYOS
# 4    GUNGOREN_DAVUTPASA_MARMARA
# 5                   SILE_DARLIK
# 6                       PASAKOY
# 7                SANCAKTEPE_MGM
# 8                       ESENLER
# 9             HACIOSMAN_SARIYER
# Name: OBSERVATORY_NAME, dtype: object

# %% [markdown]
# #### Mean
# * Ortalama alır

# %%
df["AVERAGE_TEMPERATURE"].mean()
# Out:
# 6.2374721550033945

# %% [markdown]
# #### Median
# * Küçükten büyüğe sıralar, ortadaki değeri alır

# %%
df["AVERAGE_TEMPERATURE"].median()
# Out:
# 6.179869999999999

# %% [markdown]
# #### Describe
# * Bilgileri verir

# %%
df.describe()
# Out:
#        MINIMUM_TEMPERATURE  MAXIMUM_TEMPERATURE  AVERAGE_TEMPERATURE  \
# count         53044.000000         53044.000000         53044.000000
# mean              5.912294             6.577936             6.237472
# std               2.807348             2.820318             2.799843
# min              -7.400000            -4.200000            -5.508330
# 25%               4.126750             4.744000             4.442552
# 50%               5.892000             6.500000             6.179870
# 75%               7.700000             8.340000             7.995237
# max              17.130000            43.700000            17.692590
#
#        MINIMUM_HUMIDITY  MAXIMUM_HUMIDITY  AVERAGE_HUMIDITY  MINIMUM_WIND  \
# count      53134.000000      53134.000000      53134.000000  53134.000000
# mean          78.472679         82.917722         80.738619     -3.572787
# std           17.806068         16.049181         16.860793     22.711833
# ...

# %% [markdown]
# #### Count
# * NA olmayan değerleri sayar

# %%
df["AVERAGE_TEMPERATURE"].count()
# Out:
# 53044

# %%
len(df)
# Out:
# 53134

# %%
print(str(len(df) - df["AVERAGE_TEMPERATURE"].count()) + " adet NA deger vardır")
# Out:
# 90 adet NA deger vardır

# %%
df.count()
# Out:
# DATE_TIME                   53134
# OBSERVATORY_NAME            53134
# SENSOR_TYPE                 53134
# MINIMUM_TEMPERATURE         53044
# MAXIMUM_TEMPERATURE         53044
# AVERAGE_TEMPERATURE         53044
# MINIMUM_HUMIDITY            53134
# MAXIMUM_HUMIDITY            53134
# AVERAGE_HUMIDITY            53134
# MINIMUM_WIND                53134
# MAXIMUM_WIND                53134
# AVERAGE_WIND                53134
# MINIMUM_DIRECTIONOFWIND     53134
# MAXIMUM_DIRECTIONOFWIND     53134
# AVERAGE_DIRECTIONOFWIND     53134
# MINIMUM_PRECIPITATION       53134
# MAXIMUM_PRECIPITATION       53134
# AVERAGE_PRECIPITATION       53134
# MINIMUM_ROAD_TEMPERATURE    53134
# MAXIMUM_ROAD_TEMPERATURE    53134
# AVERAGE_ROAD_TEMPERATURE    53134
# MINIMUM_FELT_TEMPERATURE    53134
# MAXIMUM_FELT_TEMPERATURE    53134
# AVERAGE_FELT_TEMPERATURE    53134
# dtype: int64

# %% [markdown]
# #### Value Counts

# %%
df["OBSERVATORY_NAME"].value_counts()
# Out:
# CIFTALAN                740
# YSS_KOPRUSU             740
# ODAYERI                 740
# SUREYYAPASA             740
# SABIHAGOKCEN            740
#                        ...
# EMINONU                 514
# FLORYA                  495
# B_CEKMECE_SVIRAJLARI    473
# KADIKOY_GOZTEPE_MGM     443
# HACIOSMAN_SARIYER       371
# Name: OBSERVATORY_NAME, Length: 76, dtype: int64

# %% [markdown]
# **Değerleri % olarak istiyorsak**

# %%
df["OBSERVATORY_NAME"].value_counts(normalize=True)
# Out:
# CIFTALAN                0.013927
# YSS_KOPRUSU             0.013927
# ODAYERI                 0.013927
# SUREYYAPASA             0.013927
# SABIHAGOKCEN            0.013927
#                           ...
# EMINONU                 0.009674
# FLORYA                  0.009316
# B_CEKMECE_SVIRAJLARI    0.008902
# KADIKOY_GOZTEPE_MGM     0.008337
# HACIOSMAN_SARIYER       0.006982
# Name: OBSERVATORY_NAME, Length: 76, dtype: float64
